# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_tmp  = pd.read_excel('Overestimation_scenarios.xlsx')

# %%
df_tmp
# Out:
#                   H2S  AEI_0 (H2S)  CDO_1 (H2S)  Unnamed: 3  \
# 0   50% overestimated     0.682376     0.812750         NaN
# 1  100% overestimated     0.784635     0.893227         NaN
# 2  200% overestimated     0.885359     0.958627         NaN
#
#                   CO2  AEI_0 (CO2)  CDO_1 (CO2)
# 0   50% overestimated     0.776060     0.763577
# 1  100% overestimated     0.820493     0.862636
# 2  200% overestimated     0.892489     0.943753

# %%
np.array(df_tmp['AEI_0 (H2S)'])
# Out:
# array([0.68237642, 0.78463482, 0.88535878])

# %%
x_H2S = np.array([1,2,3])
y_AEI_H2S = np.array(df_tmp['AEI_0 (H2S)']) 
y_CDO_H2S = np.array(df_tmp[])



plt.bar(x_AEI_H2S-0.3, y_AEI_H2S)
# Out:
# <BarContainer object of 3 artists>
